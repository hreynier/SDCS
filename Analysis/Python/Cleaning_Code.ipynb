# %%
# This code cleans the data imported from the server to the dataframe that is then used for exploratory stats,
# the regression and more. 

import pandas as pd
import pymysql
pd.set_option('display.max_rows', 200)
# %matplotlib inline

# !!! !!! !!! 
# Here need to change this as we request the data from the server
# tree = pd.read_csv('Trees_In_Camden.csv') 

# 2 steps to get data from the database 
# 1. Create the connection string to the MySQL database
from sqlalchemy import create_engine 
# replace USERNAME and PASSWORD with your own credentials 
# engine = create_engine('mysql+pymysql://zcfanko:sasuxuyuzi@dev.spatialdatacapture.org:3306/zcfanko')
# make the connection to the database
conn = engine.raw_connection()
# 2. Getting the data 
# tree = pd.read_sql('trees_Camden', conn)

#########################################################
############### Removing unwanted columns ###############
#########################################################
                       
del tree['Sequence']
del tree['Contract Area']
del tree['Removal Reason']
del tree['Outstanding Job Count']
del tree['Outstanding Job Number']
del tree['Outstanding Job Description']
del tree['Easting']
del tree['Northing']
del tree['Spatial Accuracy']
del tree['Organisation URI']
del tree['Lower Layer Super Output Area (LSOA)']
del tree['Ward']
del tree['Inspection Due Date'] 

#del tree['Identifier']

#########################################################
################ Transforming data types ################
#########################################################

#Turns date column into datetime type
tree['Inspection Date'] = pd.to_datetime(tree['Inspection Date'])
# data['Date'] = pd.to_datetime(data['Date']) !!!! 
#data['Uploaded'] = pd.to_datetime(data['Uploaded'])
tree['Last Uploaded'] = pd.to_datetime(tree['Last Uploaded'])

# True / False data 
# set up dictionary containing mapping 
d = {'Yes': True, 'No': False}
# map new vales to existing column values
tree['Tree Set To Be Removed'] = tree['Tree Set To Be Removed'].map(d)
# map new values to existing values
tree['Newly Planted'] = tree['Newly Planted'].map(d)
# transform the data type
tree['Tree Set To Be Removed'] = tree['Tree Set To Be Removed'].astype('bool')
tree['Newly Planted'] = tree['Newly Planted'].astype('bool')

#########################################################
################## Renaming variables ###################
#########################################################

tree = tree.rename(columns={'Tree Set To Be Removed': 'Removed_Soon'})
tree = tree.rename(columns = {'Number Of Trees': 'No_Trees'})
tree = tree.rename(columns = {'Site Name' : 'Site_Name'})
tree = tree.rename(columns = {'Scientific Name' : 'Sci_Name'})
tree = tree.rename(columns = {'Common Name' : 'Com_Name'})
tree = tree.rename(columns = {'Inspection Date' : 'Date'})
tree = tree.rename(columns = {'Height In Metres' : 'Height_M'})
tree = tree.rename(columns = {'Spread In Metres' : 'Spread_M'})
tree = tree.rename(columns = {'Diameter In Centimetres At Breast Height' : 'Diameter_CM'})
tree = tree.rename(columns = {'Physiological Condition' : 'Condition'})
tree = tree.rename(columns = {'Newly Planted' : 'Newly_Planted'})
tree = tree.rename(columns = {'Capital Asset Value For Amenity Trees' : 'Amenity_Value'})
tree = tree.rename(columns = {'Carbon Storage In Kilograms' : 'Carbon_StorageKG'})
tree = tree.rename(columns = {'Gross Carbon Sequestration Per Year In Kilograms' : 'Carbon_Sequest_YR'})
tree = tree.rename(columns = {'Pollution Removal Per Year In Grams' : 'Pollution_Year_grams'})
tree = tree.rename(columns = {'Ward Code' : 'Ward_Code'})
tree = tree.rename(columns = {'Ward Name' : 'Ward_Name'})
tree = tree.rename(columns = {'Longitude' : 'Lon'})
tree = tree.rename(columns = {'Latitude' : 'Lat'})
tree = tree.rename(columns = {'Location' : 'Loc'})
tree = tree.rename(columns = {'Last Uploaded' : 'Uploaded'})
tree = tree.rename(columns = {'Identifier' : 'id'})

#########################################################
############### Removing weird values ###################
#########################################################

# Remove all NAs 
# Condition!='Not applicable'Not applicable
# Condition!='Dead'
# Maturity!='Not Applicable'
tree = tree.dropna()
tree = tree[tree.Condition != 'Not applicable']
tree = tree[tree.Condition != 'Dead']
tree = tree[tree.Maturity != 'Not Applicable']

# Writing out the cleaned data to my_sql 
# tree.to_sql('NAME', con=engine) #engine defined at beginning

# %%
### IGNORE THIS, JUST TRYING TO READ IN THE DB FROM THE DB TO MAKE SURE
# VARIABLE NAMES IN CODE ABOVE ARE CORRECT' 


# !pip install pymysql
# !pip install pandas
# !pip install sodapy

import pandas as pd
from sodapy import Socrata
import requests
import pymysql
import os
import json

# import the SQLAlchemy libraries
from sqlalchemy import create_engine

# create the connection string to the MySQL database
# replace USERNAME and PASSWORD with your own credentials 
engine = create_engine('mysql+pymysql://zcfanko:sasuxuyuzi@dev.spatialdatacapture.org:3306/zcfanko')

# make the connection to the database
conn = engine.raw_connection()


trees_in_Camden = pd.read_sql('trees_Camden', con = engine)
trees_in_Camden
# Out:
# ...
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1243                     self.dialect.do_execute(
# -> 1244                         cursor, statement, parameters, context
#    1245                     )
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     549     def do_execute(self, cursor, statement, parameters, context=None):
# --> 550         cursor.execute(statement, parameters)
#     551
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# ...

# %%
self.cursor.execute("UPDATE urls SET state=%d,content='%s' WHERE url='%s'"%(state,self.conn.escape_string(content),url))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3a6d86f66334> in <module>
# ----> 1 self.cursor.execute("UPDATE urls SET state=%d,content='%s' WHERE url='%s'"%(state,self.conn.escape_string(content),url))
#
# NameError: name 'self' is not defined
